# %%
import sagemaker

sess = sagemaker.Session()
bucket = sess.default_bucket()

# !aws s3 sync s3://sagemaker-sample-files/datasets/image/caltech-101/inference/ s3://{bucket}/ground-truth-demo/images/

print('Copy and paste the below link into a web browser to confirm the ten images were successfully uploaded to your bucket:')
print(f'https://s3.console.aws.amazon.com/s3/buckets/{bucket}/ground-truth-demo/images/')

print('\nWhen prompted by Sagemaker to enter the S3 location for input datasets, you can paste in the below S3 URL')

print(f's3://{bucket}/ground-truth-demo/images/')

print('\nWhen prompted by Sagemaker to Specify a new location, you can paste in the below S3 URL')

print(f's3://{bucket}/ground-truth-demo/labeled-data/')
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# copy: s3://sagemaker-sample-files/datasets/image/caltech-101/inference/image_0007.jpeg to s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/image_0007.jpeg
# copy: s3://sagemaker-sample-files/datasets/image/caltech-101/inference/image_0016.jpeg to s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/image_0016.jpeg
# copy: s3://sagemaker-sample-files/datasets/image/caltech-101/inference/image_0019.jpeg to s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/image_0019.jpeg
# copy: s3://sagemaker-sample-files/datasets/image/caltech-101/inference/image_0061.jpeg to s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/image_0061.jpeg
# copy: s3://sagemaker-sample-files/datasets/image/caltech-101/inference/image_0151.jpeg to s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/image_0151.jpeg
# copy: s3://sagemaker-sample-files/datasets/image/caltech-101/inference/image_0068.jpeg to s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/image_0068.jpeg
# copy: s3://sagemaker-sample-files/datasets/image/caltech-101/inference/image_0059.jpeg to s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/image_0059.jpeg
# copy: s3://sagemaker-sample-files/datasets/image/caltech-101/inference/image_0123.jpeg to s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/image_0123.jpeg
# copy: s3://sagemaker-sample-files/datasets/image/caltech-101/inference/image_0271.jpeg to s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/image_0271.jpeg
# copy: s3://sagemaker-sample-files/datasets/image/caltech-101/inference/image_0260.jpeg to s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/image_0260.jpeg
# Copy and paste the below link into a web browser to confirm the ten images were successfully uploaded to your bucket:
# https://s3.console.aws.amazon.com/s3/buckets/sagemaker-us-east-1-282567728553/ground-truth-demo/images/
#
# When prompted by Sagemaker to enter the S3 location for input datasets, you can paste in the below S3 URL
# s3://sagemaker-us-east-1-282567728553/ground-truth-demo/images/
#
# When prompted by Sagemaker to Specify a new location, you can paste in the below S3 URL
# s3://sagemaker-us-east-1-282567728553/ground-truth-demo/labeled-data/
